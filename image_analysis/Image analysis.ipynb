# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline
pic = imageio.imread('me.jpg')
plt.figure(figsize = (5,5))
plt.imshow(pic)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_21340\785950015.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread('me.jpg')

# %% [markdown]
# ## Picture Info

# %%
print('Type of the image : ' , type(pic)) 
print('Shape of the image : {}'.format(pic.shape)) 
print('Image Hight {}'.format(pic.shape[0])) 
print('Image Width {}'.format(pic.shape[1])) 
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (720, 1280, 3)
# Image Hight 720
# Image Width 1280
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size)) 
print('Maximum RGB value in this image {}'.format(pic.max())) 
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 2764800
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %% [markdown]
# ## R channel

# %%
plt.title('R channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 0])
plt.show()

# %% [markdown]
# ## G channel

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 1]) 
plt.show()

# %%
plt.title('B channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 2]) 
plt.show()

# %%
pic[50:150 , : , 0] = 255 # full intensity to those pixel's R channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %% [markdown]
# ## Splitting layers

# %%
import numpy as np 
pic = imageio.imread('me.jpg') 
fig, ax = plt.subplots(nrows = 1, ncols=3, figsize=(15,5))  
for c, ax in zip(range(3), ax):     
     # create zero matrix        
     split_img = np.zeros(pic.shape, dtype="uint8") 
     # 'dtype' by default: 'numpy.float64'  # assing each channel      
     split_img[ :, :, c] = pic[ :, :, c] # display each channel     
     ax.imshow(split_img)
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_21340\1390041603.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread('me.jpg')

# %%
pic = imageio.imread('me.jpg') 
gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114])   
gray = gray(pic) 
plt.figure( figsize = (5,5))  
plt.imshow(gray, cmap = plt.get_cmap(name = 'gray')) 
plt.show()
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_21340\3732896346.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread('me.jpg')
